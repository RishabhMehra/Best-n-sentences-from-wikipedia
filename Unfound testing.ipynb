# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# %matplotlib inline

# %%
import wikipedia
print(wikipedia.WikipediaPage(title = 'Mehul Choksi').summary)
# Out:
# Mehul Chinubhai Choksi (born 5 May 1959) is a businessman of Indian origin and Antiguan citizenship, and the owner of Gitanjali Group, a retail jewellery company with 4,000 stores in India. An arrest warrant for Choksi has been issued in connection with the alleged Punjab National Bank fraud case. He was allegedly involved in stock market manipulation in 2013.

# %%
import wikipediaapi

# %%
def print_links(page):
        links = page.links
        for title in sorted(links.keys()):
            print("%s: %s" % (title, links[title]))
            
def print_categories(page):
        categories = page.categories
        for title in sorted(categories.keys()):
            print("%s: %s" % (title, categories[title]))

# %%
a=input()




# Text Preprocessing
import string
a=string.capwords(a)
a
# Out:
# prime minister of india
# 'Prime Minister Of India'

# %%
wiki_wiki = wikipediaapi.Wikipedia('en')

page_py = wiki_wiki.page(a)
if(page_py.exists()):
    print("Page - Summary: %s" % page_py.text)
    page_content=page_py.text
    #print("\n\n\n\n\n\n\nLinks Related to results")
    #print_links(page_py)
    #print("\n\n\n\n\n\n\nCategories Related to results")
    #print_categories(page_py)
else :
    print("NULL")
# Out:
# Page - Summary: The Prime Minister of India is the leader of the executive of the Government of India. The prime minister is also the chief adviser to the President of India and head of the Council of Ministers. They can be a member of any of the two houses of the Parliament of India — the Lok Sabha (House of the People) and the Rajya Sabha (Council of the States) — but has to be a member of the political party or coalition, having a majority in the Lok Sabha.
# The prime minister is the senior-most member of cabinet in the executive of government in a parliamentary system. The prime minister selects and can dismiss members of the cabinet; allocates posts to members within the government; and is the presiding member and chairperson of the cabinet.
# ...

# %%
page_content=page_content.replace('\\n', '\n')

#page_content

# %%
text_file = open("Output.txt", "w")
text_file.write("Fetched Article %s" %page_content.encode("utf-8"))
text_file.close()

# %%
#TESTING for new line

b="Abhi August chal raha hai.agla mahina sept hai.firr oct mai IA hai.firr chutti"

b=b.replace('\n','.')
#print(" %s" %b)
b
# Out:
# 'Abhi August chal raha hai.agla mahina sept hai.firr oct mai IA hai.firr chutti'

# %%
 DATE_PATTERN = ['january','february','march','april','may','june','july','august','september','october','november','december','jan','feb','mar','apr','may','jun','jul','aug','sep','sept','oct','nov','dec']

# %%
MONTHS_PATTERN
# Out:
# ['january',
#  'february',
#  'march',
#  'april',
#  'may',
#  'june',
#  'july',
#  'august',
#  'september',
#  'october',
#  'november',
#  'december',
#  'jan',
#  'feb',
#  'mar',
#  'apr',
#  'may',
#  'jun',
#  'jul',
#  'aug',
#  'sep',
#  'sept',
#  'oct',
#  'nov',
#  'dec']

# %%
lines=b.split('.')
print(lines)
sel=list()
# Out:
# ['Abhi August chal raha hai', 'agla mahina sept hai', 'firr oct mai IA hai', 'firr chutti']

# %%
for num,line in enumerate(lines):
    words=line.split(' ')
    for wn,word in enumerate(words):
        if word.lower() in MONTHS_PATTERN:
           sel.append(num)

# %%
sel
# Out:
# [0, 1, 2]

# %%
sels=list()
for x in sel:
    sels.append(lines[x])

# %%
sels
# Out:
# ['Abhi August chal raha hai', 'agla mahina sept hai', 'firr oct mai IA hai']

# %%
import Whoosh
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-165-952fde9d537b> in <module>()
# ----> 1 import Whoosh
#
# ModuleNotFoundError: No module named 'Whoosh'

# %%
page_content
# Out:
# "The Prime Minister of India is the leader of the executive of the Government of India. The prime minister is also the chief adviser to the President of India and head of the Council of Ministers. They can be a member of any of the two houses of the Parliament of India — the Lok Sabha (House of the People) and the Rajya Sabha (Council of the States) — but has to be a member of the political party or coalition, having a majority in the Lok Sabha.\nThe prime minister is the senior-most member of cabinet in the executive of government in a parliamentary system. The prime minister selects and can dismiss members of the cabinet; allocates posts to members within the government; and is the presiding member and chairperson of the cabinet.\nThe union cabinet headed by the prime minister is appointed by the President of India to assist the latter in the administration of the affairs of the executive. Union cabinet is collectively responsible to the Lok Sabha as per article 75(3) of the Consti
# ...

# %%
# Text Cleaning

# remove \n from article


page_content=page_content.replace('\n',' ')

# %%
page_content
# Out:
# "The Prime Minister of India is the leader of the executive of the Government of India. The prime minister is also the chief adviser to the President of India and head of the Council of Ministers. They can be a member of any of the two houses of the Parliament of India — the Lok Sabha (House of the People) and the Rajya Sabha (Council of the States) — but has to be a member of the political party or coalition, having a majority in the Lok Sabha. The prime minister is the senior-most member of cabinet in the executive of government in a parliamentary system. The prime minister selects and can dismiss members of the cabinet; allocates posts to members within the government; and is the presiding member and chairperson of the cabinet. The union cabinet headed by the prime minister is appointed by the President of India to assist the latter in the administration of the affairs of the executive. Union cabinet is collectively responsible to the Lok Sabha as per article 75(3) of the Constitu
# ...

# %%
#removing abbrevated text

import re
page_content=re.sub(r"\b[A-Z\.]{2,}\b"," ",page_content)

# %%
# Spliting Page line by line
page_lines=page_content.split('.')
page_lines
# Out:
# ['The Prime Minister of India is the leader of the executive of the Government of India',
#  ' The prime minister is also the chief adviser to the President of India and head of the Council of Ministers',
#  ' They can be a member of any of the two houses of the Parliament of India — the Lok Sabha (House of the People) and the Rajya Sabha (Council of the States) — but has to be a member of the political party or coalition, having a majority in the Lok Sabha',
#  ' The prime minister is the senior-most member of cabinet in the executive of government in a parliamentary system',
#  ' The prime minister selects and can dismiss members of the cabinet; allocates posts to members within the government; and is the presiding member and chairperson of the cabinet',
#  ' The union cabinet headed by the prime minister is appointed by the President of India to assist the latter in the administration of the affairs of the executive',
# ...

# %%
# Testing
import re
teststr="hi i am the i.e.  I. K. Gujral, H. D. Deve Gowda.In the general election of 2009, the mandate of UPA increased"
teststr=re.sub(r"\b[A-Z\. ]{2,}\b"," ",teststr)
teststr
# Out:
# 'hi i am the i.e Gujral,  Deve Gowda.In the general election of 2009, the mandate of increased'

# %%
page_content
# Out:
# "The Prime Minister of India is the leader of the executive of the Government of India. The prime minister is also the chief adviser to the President of India and head of the Council of Ministers. They can be a member of any of the two houses of the Parliament of India — the Lok Sabha (House of the People) and the Rajya Sabha (Council of the States) — but has to be a member of the political party or coalition, having a majority in the Lok Sabha. The prime minister is the senior-most member of cabinet in the executive of government in a parliamentary system. The prime minister selects and can dismiss members of the cabinet; allocates posts to members within the government; and is the presiding member and chairperson of the cabinet. The union cabinet headed by the prime minister is appointed by the President of India to assist the latter in the administration of the affairs of the executive. Union cabinet is collectively responsible to the Lok Sabha as per article 75(3) of the Constitu
# ...

# %%
#Testing 
teststr="Vishwanath Pratap Singh — first finance minister and then later defence minister in Rajiv's cabinet — uncovered irregularities, in what became to be known as the Bofors scandal, during his stint at the Ministry of Defence;  .  . Singh was subsequently expelled from Congress and formed the Janata Dal and — with the help of several anti-Congress parties — also formed the National Front, a coalition of many political parties In the general election of 1989, the National Front — with outside support from the Bharatiya Janata Party ( ) and the Left Front — came to power.  .  . Singh was elected prime minister. During a tenure of less than a year,  .  . Singh and his government accepted the Mandal Commission's recommendations.  .  . Singh's tenure came to an end after he ordered the arrest of   leader Lal Krishna Advani, as a result,   withdrew its outside support to the government,  .  . Singh lost the subsequent vote-of-no-confidence 146-320 and had to resign. After  .  . Singh's resignation, Chandra Shekhar — home minister in  .  . Singh's cabinet — along with 64 members of parliament (MPs) floated the Samajwadi Janata Party (Rashtriya) ( ( )), and proved a majority in the Lok Sabha with support from Congress. But his premiership did not last long, Congress proceeded to withdraw its support; Chandra Shekhar's government fell as a result, and new elections were announced In the general election of 1991, Congress — under the leadership of  .  . Narasimha Rao — formed a minority government; Rao became the first   of South Indian origin."
tests=re.sub(r"\s\.","",teststr)
tests
# Out:
# "Vishwanath Pratap Singh — first finance minister and then later defence minister in Rajiv's cabinet — uncovered irregularities, in what became to be known as the Bofors scandal, during his stint at the Ministry of Defence;   Singh was subsequently expelled from Congress and formed the Janata Dal and — with the help of several anti-Congress parties — also formed the National Front, a coalition of many political parties In the general election of 1989, the National Front — with outside support from the Bharatiya Janata Party ( ) and the Left Front — came to power.   Singh was elected prime minister. During a tenure of less than a year,   Singh and his government accepted the Mandal Commission's recommendations.   Singh's tenure came to an end after he ordered the arrest of   leader Lal Krishna Advani, as a result,   withdrew its outside support to the government,   Singh lost the subsequent vote-of-no-confidence 146-320 and had to resign. After   Singh's resignation, Chandra Shekhar —
# ...

# %%
# Update after testing
page_content=re.sub(r"\s\.","",page_content)

# %%
#updated split by lines
page_lines=page_content.split('.')
page_lines
# Out:
# ['The Prime Minister of India is the leader of the executive of the Government of India',
#  ' The prime minister is also the chief adviser to the President of India and head of the Council of Ministers',
#  ' They can be a member of any of the two houses of the Parliament of India — the Lok Sabha (House of the People) and the Rajya Sabha (Council of the States) — but has to be a member of the political party or coalition, having a majority in the Lok Sabha',
#  ' The prime minister is the senior-most member of cabinet in the executive of government in a parliamentary system',
#  ' The prime minister selects and can dismiss members of the cabinet; allocates posts to members within the government; and is the presiding member and chairperson of the cabinet',
#  ' The union cabinet headed by the prime minister is appointed by the President of India to assist the latter in the administration of the affairs of the executive',
# ...

# %%
# Creating dataframe from list
df=pd.DataFrame({'Sentence':page_lines})
df.head()
# Out:
#                                             Sentence
# 0  The Prime Minister of India is the leader of t...
# 1   The prime minister is also the chief adviser ...
# 2   They can be a member of any of the two houses...
# 3   The prime minister is the senior-most member ...
# 4   The prime minister selects and can dismiss me...

# %%
df.describe()
# Out:
#                                                  Sentence
# count                                                 140
# unique                                                140
# top      In addition to the development of infrastruct...
# freq                                                    1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 1 columns):
# Sentence    140 non-null object
# dtypes: object(1)
# memory usage: 1.2+ KB

# %%
 # Date Finding
DATE_PATTERN = ['january','february','march','april','may','june','july','august','september','october','november','december','jan','feb','mar','apr','may','jun','jul','aug','sep','sept','oct','nov','dec','today','tomorrow','yesterday']

# %%
# Testing for date
r=[]
s=['He served from 1947 to 1964','he died','some random date','his son took over in 1964']
for x in s:
    l=re.search(r"(\d{4})",x)
    if l:
        h=int(l.group(0))
        if h<1950:
            r.append(l.group(0))
        else:
            r.append('none')
    else:
        r.append('none')

r
dft=pd.DataFrame({'sentence':s})
dft
# Out:
#                       sentence
# 0  He served from 1947 to 1964
# 1                      he died
# 2             some random date
# 3    his son took over in 1964

# %%
dft['Year']=r
dft
# Out:
#                       sentence  Year
# 0  He served from 1947 to 1964  1947
# 1                      he died  none
# 2             some random date  none
# 3    his son took over in 1964  none

# %%
dft.date[0]
# Out:
# '1947'

# %%
df.drop('Year',axis=1,inplace=True)

# %%
# Forming a year column in dataframe
Years_line=[]
for x in page_lines:
    l=re.search(r"(\d{4})",x)
    if l:
        h=int(l.group(0))
        if h<2099:
            Years_line.append(h)
        else:
            Years_line.append(None)
    else:
        Years_line.append(None)
df['Year']=Years_line
df
# Out:
#                                               Sentence    Year
# 0    The Prime Minister of India is the leader of t...     NaN
# 1     The prime minister is also the chief adviser ...     NaN
# 2     They can be a member of any of the two houses...     NaN
# 3     The prime minister is the senior-most member ...     NaN
# 4     The prime minister selects and can dismiss me...     NaN
# 5     The union cabinet headed by the prime ministe...     NaN
# 6     Union cabinet is collectively responsible to ...     NaN
# 7     The prime minister has to enjoy the confidenc...     NaN
# 8      Origins and history India follows a parliame...     NaN
# 9     In such systems, the head of state, or, the h...     NaN
# 10   , the monarch, president, or governor-general)...     NaN
# 11    The prime minister — if they are not already ...     NaN
# 12      prime minister is expected to work with oth...     NaN
# 13     History 1947-1984 Since 1947, there have bee...  1947.0
# ...

# %%
df.describe()
# Out:
#               Year
# count    35.000000
# mean   1982.314286
# std      21.137883
# min    1947.000000
# 25%    1963.000000
# 50%    1984.000000
# 75%    1999.000000
# max    2014.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 2 columns):
# Sentence    140 non-null object
# Year        35 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 2.3+ KB

# %%
df.Year.value_counts()
# Out:
# 1947.0    3
# 1999.0    3
# 1961.0    3
# 1984.0    2
# 1996.0    2
# 1998.0    2
# 1965.0    1
# 1964.0    1
# 1980.0    1
# 1989.0    1
# 2000.0    1
# 2004.0    1
# 2008.0    1
# 1948.0    1
# 2009.0    1
# 1979.0    1
# 1991.0    1
# 1951.0    1
# 1975.0    1
# 2002.0    1
# 2014.0    1
# 2010.0    1
# 1962.0    1
# 1971.0    1
# 1977.0    1
# 2005.0    1
# Name: Year, dtype: int64

# %%
# testing for month 
m="India's first prime minister — Jawaharlal Nehru — took oath on 15  1947.In February 1999, the India and Pakistan signed the Lahore Declaration, in which the two countries announced their intention to annul mutual enmity, increase trade and use their nuclear capabilities for peaceful purposes. In May 1999, All India Anna Dravida Munnetra Kazhagam (AIADMK) withdrew from the ruling National Democratic Alliance (NDA) coalition; Vajpayee's government — hence — became a caretaker one after losing a motion-of-no-confidence 269-270, this coincided with the Kargil War with Pakistan.Rao, however, did complete five continuous years in office, becoming the first prime minister outside of the Nehru—Gandhi family to do so.After the end of Rao's tenure in May 1996, the nation saw four prime ministers in a span of three years, viz., two tenures of Atal Bihari Vajpayee; one tenure of H. D. Deve Gowda from 1 June 1996 to 21 April 1997; and one tenure of I. K. Gujral from 21 April 1997 to 19 March 1998.While the work of the government is generally divided into various Ministries, the prime minister may retain certain portfolios if they are not allocated to any member of the cabinet."
mlist=m.split('.')

mlist
# Out:
# ["India's first prime minister — Jawaharlal Nehru — took oath on 15  1947",
#  'In February 1999, the India and Pakistan signed the Lahore Declaration, in which the two countries announced their intention to annul mutual enmity, increase trade and use their nuclear capabilities for peaceful purposes',
#  " In May 1999, All India Anna Dravida Munnetra Kazhagam (AIADMK) withdrew from the ruling National Democratic Alliance (NDA) coalition; Vajpayee's government — hence — became a caretaker one after losing a motion-of-no-confidence 269-270, this coincided with the Kargil War with Pakistan",
#  'Rao, however, did complete five continuous years in office, becoming the first prime minister outside of the Nehru—Gandhi family to do so',
#  "After the end of Rao's tenure in May 1996, the nation saw four prime ministers in a span of three years, viz",
#  ', two tenures of Atal Bihari Vajpayee; one tenure of H',
#  ' D',
#  ' Deve Gowda from 1 June 1996 to 21 April 1997; and one tenure of I',
# ...

# %%
mname=set()
for num,line in enumerate(mlist):
    l=re.search(r"(\d{4})",line)
    if l:
        h=l.group(0)
        if int(h)<2099:
            mname.add(num)
    words=line.split(' ')
    for wn,word in enumerate(words):
        if word.lower() in MONTHS_PATTERN:
            mname.add(num)
    
mname
# Out:
# {0, 1, 2, 4, 7, 9, 10}

# %%
# testing sets in dataframe

sdf=pd.DataFrame({'Sentence':mlist})
for x in mname:
    sdf.at[x, 'Date Present']=1
sdf
# Out:
#                                              Sentence  Date Present
# 0   India's first prime minister — Jawaharlal Nehr...           1.0
# 1   In February 1999, the India and Pakistan signe...           1.0
# 2    In May 1999, All India Anna Dravida Munnetra ...           1.0
# 3   Rao, however, did complete five continuous yea...           NaN
# 4   After the end of Rao's tenure in May 1996, the...           1.0
# 5   , two tenures of Atal Bihari Vajpayee; one ten...           NaN
# 6                                                   D           NaN
# 7    Deve Gowda from 1 June 1996 to 21 April 1997;...           1.0
# 8                                                   K           NaN
# 9          Gujral from 21 April 1997 to 19 March 1998           1.0
# 10  While the work of the government is generally ...           1.0
# 11                                                              NaN

# %% [markdown]
# # Updating after month
# # new Column -Date Present

# %%
dpset=set()
for num,line in enumerate(page_lines):
    l=re.search(r"(\d{4})",line)
    if l:
        h=l.group(0)
        if int(h)<2099:
            dpset.add(num)
    words=line.split(' ')
    for wn,word in enumerate(words):
        if word.lower() in MONTHS_PATTERN:
            dpset.add(num)
for x in dpset:
    df.at[x, 'Date Present']=1

df
# Out:
#                                               Sentence    Year  Date Present
# 0    The Prime Minister of India is the leader of t...     NaN           NaN
# 1     The prime minister is also the chief adviser ...     NaN           NaN
# 2     They can be a member of any of the two houses...     NaN           NaN
# 3     The prime minister is the senior-most member ...     NaN           NaN
# 4     The prime minister selects and can dismiss me...     NaN           NaN
# 5     The union cabinet headed by the prime ministe...     NaN           NaN
# 6     Union cabinet is collectively responsible to ...     NaN           NaN
# 7     The prime minister has to enjoy the confidenc...     NaN           NaN
# 8      Origins and history India follows a parliame...     NaN           NaN
# 9     In such systems, the head of state, or, the h...     NaN           NaN
# 10   , the monarch, president, or governor-general)...     NaN           NaN
# ...

# %%
df.describe()
# Out:
#               Year  Date Present
# count    35.000000          39.0
# mean   1982.314286           1.0
# std      21.137883           0.0
# min    1947.000000           1.0
# 25%    1963.000000           1.0
# 50%    1984.000000           1.0
# 75%    1999.000000           1.0
# max    2014.000000           1.0

# %%
df['Date Present'].value_counts()
# Out:
# 1.0    39
# Name: Date Present, dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.describe()
# Out:
#               Year  Date Present
# count    35.000000          35.0
# mean   1982.314286           1.0
# std      21.137883           0.0
# min    1947.000000           1.0
# 25%    1963.000000           1.0
# 50%    1984.000000           1.0
# 75%    1999.000000           1.0
# max    2014.000000           1.0

# %%
df.Year.value_counts()
# Out:
# 1947.0    3
# 1999.0    3
# 1961.0    3
# 1984.0    2
# 1996.0    2
# 1998.0    2
# 2009.0    1
# 2008.0    1
# 1964.0    1
# 1965.0    1
# 1971.0    1
# 1975.0    1
# 1977.0    1
# 1979.0    1
# 1980.0    1
# 2010.0    1
# 1989.0    1
# 1991.0    1
# 1951.0    1
# 1962.0    1
# 2014.0    1
# 2000.0    1
# 2002.0    1
# 2004.0    1
# 2005.0    1
# 1948.0    1
# Name: Year, dtype: int64

# %%
df.isnull()
# Out:
#     Sentence   Year  Date Present
# 0      False  False         False
# 1      False  False         False
# 2      False  False         False
# 3      False  False         False
# 4      False  False         False
# 5      False  False         False
# 6      False  False         False
# 7      False  False         False
# 8      False  False         False
# 9      False  False         False
# 10     False  False         False
# 11     False  False         False
# 12     False  False         False
# 13     False  False         False
# 14     False  False         False
# 15     False  False         False
# 16     False  False         False
# 17     False  False         False
# 18     False  False         False
# 19     False  False         False
# 20     False  False         False
# 21     False  False         False
# 22     False  False         False
# 23     False  False         False
# 24     False  False         False
# 25     False  False         False
# ...

# %%
df
# Out:
#                                              Sentence    Year  Date Present
# 0     History 1947-1984 Since 1947, there have bee...  1947.0           1.0
# 1    The first few decades after 1947 saw the Indi...  1947.0           1.0
# 2    India's first prime minister — Jawaharlal Neh...  1947.0           1.0
# 3          His tenure ended in May 1964, on his death  1964.0           1.0
# 4    Shastri's tenure saw the Indo-Pakistani War o...  1965.0           1.0
# 5    In addition, events such as the Indo-Pakistan...  1971.0           1.0
# 6    In 1975, President Fakhruddin Ali Ahmed — on ...  1975.0           1.0
# 7    All of the political parties of the oppositio...  1977.0           1.0
# 8    Ultimately, after two and a half years as  ; ...  1979.0           1.0
# 9    In 1980, after a three-year absence, the Cong...  1980.0           1.0
# 10   Subsequently, on 31 October 1984, Indira was ...  1984.0           1.0
# ...

# %%
df.iloc[38]['Sentence']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-379-cff2b767ecf1> in <module>()
# ----> 1 df.iloc[38]['Sentence']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2100
#    2101             # validate the location
# -> 2102             self._validate_integer(key, axis)
#    2103
#    2104             return self._get_loc(key, axis=axis)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    2007         l = len(ax)
# ...

# %%
df=df.reset_index(drop=True)

# %%
df
# Out:
#                                              Sentence    Year  Date Present
# 0     History 1947-1984 Since 1947, there have bee...  1947.0           1.0
# 1    The first few decades after 1947 saw the Indi...  1947.0           1.0
# 2    India's first prime minister — Jawaharlal Neh...  1947.0           1.0
# 3          His tenure ended in May 1964, on his death  1964.0           1.0
# 4    Shastri's tenure saw the Indo-Pakistani War o...  1965.0           1.0
# 5    In addition, events such as the Indo-Pakistan...  1971.0           1.0
# 6    In 1975, President Fakhruddin Ali Ahmed — on ...  1975.0           1.0
# 7    All of the political parties of the oppositio...  1977.0           1.0
# 8    Ultimately, after two and a half years as  ; ...  1979.0           1.0
# 9    In 1980, after a three-year absence, the Cong...  1980.0           1.0
# 10   Subsequently, on 31 October 1984, Indira was ...  1984.0           1.0
# ...

# %%
df.iloc[28]['Sentence']
# Out:
# ' not hold any office of profit under the Government of India or the government of any state or under any local or other authority subject to the control of any of the said governments If however a candidate is elected as the prime minister they must vacate their post from any private or government company and may take up the post only on completion of their term'

# %%
df.iloc[38]['Sentence']
# Out:
# ' Donations to the   are 100% tax-deductible under section 80G of the Income Tax Act, 1961'

# %%
MONTHS_PATTERN
# Out:
# ['january',
#  'february',
#  'march',
#  'april',
#  'may',
#  'june',
#  'july',
#  'august',
#  'september',
#  'october',
#  'november',
#  'december',
#  'jan',
#  'feb',
#  'mar',
#  'apr',
#  'may',
#  'jun',
#  'jul',
#  'aug',
#  'sep',
#  'sept',
#  'oct',
#  'nov',
#  'dec']

# %%
DATE_PATTERN
# Out:
# ['january',
#  'february',
#  'march',
#  'april',
#  'may',
#  'june',
#  'july',
#  'august',
#  'september',
#  'october',
#  'november',
#  'december',
#  'jan',
#  'feb',
#  'mar',
#  'apr',
#  'may',
#  'jun',
#  'jul',
#  'aug',
#  'sep',
#  'sept',
#  'oct',
#  'nov',
#  'dec',
#  'today',
#  'tomorrow',
#  'yesterday']

# %%
df.iloc[0]['Sentence']
# Out:
# '  History 1947-1984 Since 1947, there have been 14 different prime ministers'

# %% [markdown]
# # BEST SENTENCES Testing

# %% [markdown]
#  Convert sentence to vector using doc2vec

# %%
from gensim.models import doc2vec
from collections import namedtuple

# Load data

doc1 =sdf['Sentence']

# Transform data (you can add more data preprocessing steps) 

docs = []
analyzedDocument = namedtuple('AnalyzedDocument', 'words tags')
for i, text in enumerate(doc1):
    words = text.lower().split()
    tags = [i]
    docs.append(analyzedDocument(words, tags))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\utils.py:1209: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
# Train model (set min_count = 1, if you want the model to work with the provided example data set)

model = doc2vec.Doc2Vec(docs, size = 100, window = 300, min_count = 1, workers = 4)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\models\doc2vec.py:535: UserWarning: The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.
#   warnings.warn("The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.")
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay

# %%
tokens =a.split()

new_vector = model.infer_vector(tokens)
sims = model.docvecs.most_similar([new_vector],topn=12)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):

# %%
sims
# Out:
# [(6, 0.12102904170751572),
#  (9, 0.11395687609910965),
#  (11, 0.08596783876419067),
#  (0, 0.08204623311758041),
#  (1, 0.06882830709218979),
#  (10, 0.06519132852554321),
#  (3, 0.0427265465259552),
#  (2, 0.02819748781621456),
#  (7, 0.02002170868217945),
#  (8, -0.03044358640909195),
#  (5, -0.036092936992645264),
#  (4, -0.09782928973436356)]

# %%
r=[i[0] for i in sims]

# %%
r
# Out:
# [6, 9, 11, 0, 1, 10, 3, 2, 7, 8, 5, 4]

# %%
r[0]
# Out:
# 6

# %%
sdf.shape[0]
# Out:
# 12

# %%
sdf['Rank']=r

# %%
sdf
# Out:
#                                              Sentence  Date Present  Rank
# 0   India's first prime minister — Jawaharlal Nehr...           1.0     6
# 1   In February 1999, the India and Pakistan signe...           1.0     9
# 2    In May 1999, All India Anna Dravida Munnetra ...           1.0    11
# 3   Rao, however, did complete five continuous yea...           NaN     0
# 4   After the end of Rao's tenure in May 1996, the...           1.0     1
# 5   , two tenures of Atal Bihari Vajpayee; one ten...           NaN    10
# 6                                                   D           NaN     3
# 7    Deve Gowda from 1 June 1996 to 21 April 1997;...           1.0     2
# 8                                                   K           NaN     7
# 9          Gujral from 21 April 1997 to 19 March 1998           1.0     8
# 10  While the work of the government is generally ...           1.0     5
# 11                                                              NaN     4

# %% [markdown]
# # Best Sentences Updated

# %%
# Store Value of number of rows
nr=df.shape[0]

# %%
from gensim.models import doc2vec
from collections import namedtuple

# Load data

doc1 =df['Sentence']

# Transform data (you can add more data preprocessing steps) 

docs = []
analyzedDocument = namedtuple('AnalyzedDocument', 'words tags')
for i, text in enumerate(doc1):
    words = text.lower().split()
    tags = [i]
    docs.append(analyzedDocument(words, tags))

# Train model (set min_count = 1, if you want the model to work with the provided example data set)

model = doc2vec.Doc2Vec(docs, size = 100, window = 300, min_count = 1, workers = 4)


tokens =a.split()

new_vector = model.infer_vector(tokens)
sim_list = model.docvecs.most_similar([new_vector],topn=nr)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\models\doc2vec.py:535: UserWarning: The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.
#   warnings.warn("The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.")
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):

# %%
#Rank to each sentence
rank=[i[0] for i in sim_list]

# %%
df['Ranking']=rank

# %%
df
# Out:
#                                              Sentence    Year  Date Present  \
# 0     History 1947-1984 Since 1947, there have bee...  1947.0           1.0
# 1    The first few decades after 1947 saw the Indi...  1947.0           1.0
# 2    India's first prime minister — Jawaharlal Neh...  1947.0           1.0
# 3          His tenure ended in May 1964, on his death  1964.0           1.0
# 4    Shastri's tenure saw the Indo-Pakistani War o...  1965.0           1.0
# 5    In addition, events such as the Indo-Pakistan...  1971.0           1.0
# 6    In 1975, President Fakhruddin Ali Ahmed — on ...  1975.0           1.0
# 7    All of the political parties of the oppositio...  1977.0           1.0
# 8    Ultimately, after two and a half years as  ; ...  1979.0           1.0
# 9    In 1980, after a three-year absence, the Cong...  1980.0           1.0
# 10   Subsequently, on 31 October 1984, Indira was ...  1984.0           1.0
# ...

# %%
# Number of best Lines

no_best_lines=input()
# Out:
# 5

# %%
nbest_lines=list()
nyear=list()
for index, row in df.iterrows():
    if row['Ranking'] < int(no_best_lines):
        print (row['Year'],':', row['Sentence'])
        nbest_lines.append(row['Sentence'])
        nyear.append(row['Year'])
# Out:
# 1971.0 :  In addition, events such as the Indo-Pakistani War of 1971; the establishment of a sovereign Bangladesh; accession of Sikkim to India, through a referendum in 1975; and India's first nuclear test in Pokhran occurred during Indira's first term
# 1979.0 :  Ultimately, after two and a half years as  ; on 28 July 1979, Morarji tendered his resignation to the president; and his government fell
# 1991.0 :  But his premiership did not last long, Congress proceeded to withdraw its support; Chandra Shekhar's government fell as a result, and new elections were announced In the general election of 1991, Congress — under the leadership of   Narasimha Rao — formed a minority government; Rao became the first   of South Indian origin
# 1998.0 :  The government of Prime Minister Vajpayee — elected in 1998 — took some concrete steps
# 2010.0 :  In 2010, the prime minister's office reported that he/she does not receive a formal salary, but was only entitled to monthly allowances

# %%
# Sentence Embedding 


nbest_docs = []
analyzedDocument = namedtuple('AnalyzedDocument', 'words tags')
for i, text in enumerate(nbest_lines):
    words = text.lower().split()
    tags = [i]
    nbest_docs.append(analyzedDocument(words, tags))

# %%
# Model to Convert Best sentences to Vector format

best_model = doc2vec.Doc2Vec(nbest_docs, size = 100, window = 300, min_count = 1, workers = 4)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\models\doc2vec.py:535: UserWarning: The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.
#   warnings.warn("The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.")
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay

# %%
# Displaying N best sentences with Sentence Embedding

for num,i in enumerate (best_model.docvecs):
    if num<int(no_best_lines):
        print(nyear[num],':',nbest_lines[num])
        print(best_model.docvecs[num])
# Out:
# 1971.0 :  In addition, events such as the Indo-Pakistani War of 1971; the establishment of a sovereign Bangladesh; accession of Sikkim to India, through a referendum in 1975; and India's first nuclear test in Pokhran occurred during Indira's first term
# [ 2.7540305e-03  9.9845207e-04  2.2466183e-03  5.6167867e-04
#   7.6700392e-04 -4.9980092e-03  3.8409671e-03 -8.5072615e-04
#   1.7882066e-03 -1.7101907e-03  7.6505961e-04 -2.5082594e-03
#   2.3654413e-03 -2.6484972e-03 -2.2620682e-03  3.5045177e-03
#  -4.8216034e-04  1.4079799e-03 -3.8567085e-03  2.9150030e-04
#  -2.8521128e-03  3.9073676e-03  1.4057147e-03  1.6934291e-03
#  -3.5624644e-03  6.8107952e-04  2.6505359e-03  1.7966976e-03
#  -2.8389720e-03  3.2367641e-03  1.5806829e-03 -3.9459118e-03
#  -2.4632749e-03  4.1802102e-03  2.9443339e-03 -3.3533068e-03
#  -2.6603204e-03 -2.8369240e-03 -1.2001385e-03  3.1780128e-03
#   2.3158907e-03 -3.0866836e-03  1.7620156e-03 -3.1683794e-03
# ...
